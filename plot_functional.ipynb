# %%
from ansp.graph import darw_full_graph
darw_full_graph("select_runs/Minecraft", "creft")
# Out:
# ['run242.csv', 'run243.csv', 'run241.csv', 'run237.csv', 'run236.csv', 'run235.csv', 'run239.csv', 'run238.csv', 'run240.csv']
